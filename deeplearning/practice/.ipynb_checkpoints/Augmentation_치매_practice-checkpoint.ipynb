# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, initializers, regularizers, metrics

np.random.seed(3)
tf.random.set_seed(3)

train_datagen = ImageDataGenerator(rescale = 1./255, # 이미지 크기 바꾸기. 0~255의 RGB값 가짐.
                                  horizontal_flip = True, # 이미지 수평 뒤집기
                                  width_shift_range = 0.1,# 전체크기의 10% 범위에서 수평이동
                                  height_shift_range = 0.1, # 수직이동
                                   rotation_range = 5, # 정해진 각도만큼 이미지 회전시키기
                                   shear_range = 0.7, # 좌표 하나 고정시키고 몇개의 좌표 이동.
                                   zoom_range = 1.2, # 축소 또는 확대
                                   vertical_flip = True, # 이미지 수직 뒤집기
                                  fill_mode = 'nearest')

train_generator = train_datagen.flow_from_directory('./train',
                                                   target_size = (150, 150), # 이미지 크기
                                                   batch_size = 5,
                                                   class_mode = 'binary') # 2진분류

# 테스트셋은 이미지 부풀리기 과정 진행 안함. 정규화 작업만하기.
test_datagen = ImageDataGenerator(rescale = 1./255)


test_generator = test_datagen.flow_from_directory('./test',
                                                  target_size = (150, 150),
                                                  batch_size = 5,
                                                  class_mode = 'binary')

# CNN 모델 적용하기
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

model.summary()
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_5 (Activation)    (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_6 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_7 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_8 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# _________________________________________________________________
# activation_9 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 1,212,578
# Trainable params: 1,212,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일하기
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.0002),
             metrics = ['accuracy'])

# 모델 실행하기
history = model.fit_generator(train_generator, 
                              steps_per_epoch = 100, 
                              epochs = 20,
                             validation_data = test_generator, 
                              validation_steps = 4)

# 결과 그래프로 표현하기
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker = '.', c = "red", label = 'Trainset_acc')
plt.plot(x_len, val_acc, marker = '.', c = "lightcoral", label = 'Testset_acc')
plt.plot(x_len, y_vloss, marker = '.', c = "blue", label = 'Testset_loss')
plt.plot(x_len, y_loss, marker = '.', c = 'blue', label = 'Trainset_loss')

plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
#  32/100 [========>.....................] - ETA: 3s - loss: 0.6973 - accuracy: 0.4808WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2000 batches). You may need to use the repeat() function when building your dataset.
# 100/100 [==============================] - 2s 20ms/step - loss: 0.6974 - accuracy: 0.4684 - val_loss: 0.6831 - val_accuracy: 0.5500

# %%
# 모델 컴파일하기
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.0002),
             metrics = ['accuracy'])

# 모델 실행하기
history = model.fit_generator(train_generator,  # steps_per_epoch = 100일때는 안나옴..
                              steps_per_epoch = 30, # 한번의 epoch에서 훈련에 사용할 배치의 개수 지정
                              epochs = 20, # 데이터 셋 20번 훈련
                              validation_data = test_generator, 
                              validation_steps = 4) # 한번의 epoch가 끝날 때 테스트에 사용되는 배치 수 지정

# 결과 그래프로 표현하기
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker = '.', c = "red", label = 'Trainset_acc')
plt.plot(x_len, val_acc, marker = '.', c = "lightcoral", label = 'Testset_acc')
plt.plot(x_len, y_vloss, marker = '.', c = "blue", label = 'Testset_loss')
plt.plot(x_len, y_loss, marker = '.', c = 'blue', label = 'Trainset_loss')

plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 30/30 [==============================] - 2s 64ms/step - loss: 0.7004 - accuracy: 0.4901 - val_loss: 0.7179 - val_accuracy: 0.3000
# Epoch 2/20
# 30/30 [==============================] - 2s 59ms/step - loss: 0.6861 - accuracy: 0.5539 - val_loss: 0.6680 - val_accuracy: 0.8500
# Epoch 3/20
# 30/30 [==============================] - 2s 59ms/step - loss: 0.6894 - accuracy: 0.4898 - val_loss: 0.6697 - val_accuracy: 0.5500
# Epoch 4/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.6785 - accuracy: 0.5699 - val_loss: 0.6783 - val_accuracy: 0.5000
# Epoch 5/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.6725 - accuracy: 0.6351 - val_loss: 0.6323 - val_accuracy: 0.6500
# Epoch 6/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.6472 - accuracy: 0.5716 - val_loss: 0.6850 - val_accuracy: 0.4000
# Epoch 7/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.6136 - accuracy: 0.7381 - val_loss: 0.5991 - val_accuracy: 0.7500
# Epoch 8/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.6383 - accuracy: 0.6274 - val_loss: 0.5613 - val_accuracy: 0.8500
# Epoch 9/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.5520 - accuracy: 0.8124 - val_loss: 0.6314 - val_accuracy: 0.5000
# Epoch 10/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.5815 - accuracy: 0.6756 - val_loss: 0.5493 - val_accuracy: 0.7500
# Epoch 11/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.5606 - accuracy: 0.6521 - val_loss: 0.4620 - val_accuracy: 0.8500
# Epoch 12/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.5869 - accuracy: 0.7078 - val_loss: 0.4314 - val_accuracy: 0.9500
# Epoch 13/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.5260 - accuracy: 0.8091 - val_loss: 0.4899 - val_accuracy: 0.7500
# Epoch 14/20
# 30/30 [==============================] - 2s 62ms/step - loss: 0.5505 - accuracy: 0.7147 - val_loss: 0.4439 - val_accuracy: 0.7000
# Epoch 15/20
# 30/30 [==============================] - 2s 67ms/step - loss: 0.4892 - accuracy: 0.7417 - val_loss: 0.4710 - val_accuracy: 0.7000
# Epoch 16/20
# 30/30 [==============================] - 2s 70ms/step - loss: 0.4728 - accuracy: 0.8097 - val_loss: 0.2761 - val_accuracy: 1.0000
# Epoch 17/20
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4462 - accuracy: 0.8289 - val_loss: 0.2876 - val_accuracy: 1.0000
# Epoch 18/20
# 30/30 [==============================] - 2s 62ms/step - loss: 0.4108 - accuracy: 0.7965 - val_loss: 0.5098 - val_accuracy: 0.8000
# Epoch 19/20
# 30/30 [==============================] - 2s 63ms/step - loss: 0.6081 - accuracy: 0.7475 - val_loss: 0.2819 - val_accuracy: 0.9000
# Epoch 20/20
# 30/30 [==============================] - 2s 66ms/step - loss: 0.4518 - accuracy: 0.7926 - val_loss: 0.5642 - val_accuracy: 0.5500

# %%
# 모델 컴파일하기
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.0002),
             metrics = ['accuracy'])

# 모델 실행하기
history = model.fit_generator(train_generator,  # steps_per_epoch = 100일때는 안나옴..
                              steps_per_epoch = 30, # 한번의 epoch에서 훈련에 사용할 배치의 개수 지정
                              epochs = 20, # 데이터 셋 20번 훈련
                              validation_data = test_generator, 
                              validation_steps = 4,# 한번의 epoch가 끝날 때 테스트에 사용되는 배치 수 지정
                              verbose = 2)

# - 0:출력 x, 1:훈련의 진행도를 막대로 보여줌, 2:미니 배치마다 손실 정보 출력


# 결과 그래프로 표현하기
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker = '.', c = "red", label = 'Trainset_acc')
plt.plot(x_len, val_acc, marker = '.', c = "lightcoral", label = 'Testset_acc')
plt.plot(x_len, y_vloss, marker = '.', c = "blue", label = 'Testset_loss')
plt.plot(x_len, y_loss, marker = '.', c = 'blue', label = 'Trainset_loss')

plt.legend(loc = 'upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 30/30 - 2s - loss: 0.4592 - accuracy: 0.7933 - val_loss: 0.2980 - val_accuracy: 0.8500
# Epoch 2/20
# 30/30 - 2s - loss: 0.3652 - accuracy: 0.8533 - val_loss: 0.2562 - val_accuracy: 0.9000
# Epoch 3/20
# 30/30 - 2s - loss: 0.5052 - accuracy: 0.7333 - val_loss: 0.3518 - val_accuracy: 0.8000
# Epoch 4/20
# 30/30 - 2s - loss: 0.4043 - accuracy: 0.8200 - val_loss: 0.1622 - val_accuracy: 1.0000
# Epoch 5/20
# 30/30 - 2s - loss: 0.3724 - accuracy: 0.8667 - val_loss: 0.2884 - val_accuracy: 0.9000
# Epoch 6/20
# 30/30 - 2s - loss: 0.3881 - accuracy: 0.8333 - val_loss: 0.3067 - val_accuracy: 0.8500
# Epoch 7/20
# 30/30 - 2s - loss: 0.3889 - accuracy: 0.8067 - val_loss: 0.2819 - val_accuracy: 0.9500
# Epoch 8/20
# 30/30 - 2s - loss: 0.4076 - accuracy: 0.8200 - val_loss: 0.2150 - val_accuracy: 0.9000
# Epoch 9/20
# 30/30 - 2s - loss: 0.3350 - accuracy: 0.8733 - val_loss: 0.1996 - val_accuracy: 0.9000
# Epoch 10/20
# 30/30 - 2s - loss: 0.3214 - accuracy: 0.8800 - val_loss: 0.2391 - val_accuracy: 0.8500
# Epoch 11/20
# 30/30 - 2s - loss: 0.3512 - accuracy: 0.8467 - val_loss: 0.2575 - val_accuracy: 0.8500
# Epoch 12/20
# 30/30 - 2s - loss: 0.3292 - accuracy: 0.8533 - val_loss: 0.3254 - val_accuracy: 0.8500
# Epoch 13/20
# 30/30 - 2s - loss: 0.3677 - accuracy: 0.8667 - val_loss: 0.1969 - val_accuracy: 0.9000
# Epoch 14/20
# 30/30 - 2s - loss: 0.3321 - accuracy: 0.8200 - val_loss: 0.1266 - val_accuracy: 0.9500
# Epoch 15/20
# 30/30 - 2s - loss: 0.3164 - accuracy: 0.8733 - val_loss: 0.1512 - val_accuracy: 0.9500
# Epoch 16/20
# 30/30 - 2s - loss: 0.3541 - accuracy: 0.8267 - val_loss: 0.1926 - val_accuracy: 0.9000
# Epoch 17/20
# 30/30 - 2s - loss: 0.3006 - accuracy: 0.8733 - val_loss: 0.1333 - val_accuracy: 0.9000
# Epoch 18/20
# 30/30 - 2s - loss: 0.3275 - accuracy: 0.8733 - val_loss: 0.3382 - val_accuracy: 0.8000
# Epoch 19/20
# 30/30 - 2s - loss: 0.3936 - accuracy: 0.8467 - val_loss: 0.1050 - val_accuracy: 0.9500
# Epoch 20/20
# 30/30 - 2s - loss: 0.2630 - accuracy: 0.9200 - val_loss: 0.0663 - val_accuracy: 1.0000
